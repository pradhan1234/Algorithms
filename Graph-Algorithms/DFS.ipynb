# %%
print("DFS Algorithm Implementation:")
# Out:
# DFS Algorithm Implementation:

# %%
# graph = {
#     0: [1, 2],
#     1: [0, 2, 4, 5],
#     2: [0, 1, 3, 6],
#     3: [2],
#     4: [1, 5],
#     5: [1, 4, 6],
#     6: [2, 5],
#     7: [8],
#     8: [7, 9],
#     9: [8]
# }

graph = {
    's': ['z', 'w'],
    't': ['v', 'u'],
    'u': ['t', 'v'],
    'v': ['s', 'w'],
    'w': ['x'],
    'x': ['z'],
    'y': ['x'],
    'z': ['y', 'w'],
}

# graph = {
#     0: [1, 2],
#     1: [0, 2],
#     2: [0, 1, 3, 4],
#     3: [2, 4],
#     4: [2, 3],
#     5: [6],
#     6: [5, 7],
#     7: [6],
#     8: [9],
#     9: [8],
#     10: []
# }

# %%
# color = ['white' for u in graph]
# parent = [None for u in graph]
# start = [-1 for u in graph]
# finish = [-1 for u in graph]
# t = 0

color = {}
parent = {}
start = {}
finish = {}
t = 0

for u in graph:
    color[u] = 'white'
    parent[u] = None
    start[u] = -1
    finish[u] = -1

def dfs(graph):

    for u in graph:
        if color[u] == 'white':
            dfs_visit(graph, u)
            
def dfs_visit(graph, u):
    
    color[u] = 'gray'
    global t
    t += 1
    start[u] = t
    
    printInfo(u)
        
    for v in graph[u]:
        if color[v] == 'white':
            parent[v] = u
            dfs_visit(graph, v)
            printInfo(u) 
                   
    t += 1
    finish[u] = t
    color[u] = 'black'
    
    printInfo(u)
    
def printInfo(u):
    print("Node:", u)
    print("Color:", color[u])
    print("Start:", start[u])
    print("Finish:", finish[u])
    print("Parent:", parent[u])
    print()
    
def printAllInfo(graph):
    
    print("Node\t Start\t Finish\t Parent")
    for u in graph:
        print(u, "\t", start[u], "\t", finish[u], "\t", parent[u])

# %%
dfs(graph)
# Out:
# Node: s
# Color: gray
# Start: 1
# Finish: -1
# Parent: None
#
# Node: z
# Color: gray
# Start: 2
# Finish: -1
# Parent: s
#
# Node: y
# Color: gray
# Start: 3
# Finish: -1
# Parent: z
#
# Node: x
# Color: gray
# Start: 4
# Finish: -1
# Parent: y
#
# Node: x
# Color: black
# Start: 4
# Finish: 5
# Parent: y
#
# Node: y
# Color: gray
# Start: 3
# Finish: -1
# Parent: z
#
# Node: y
# Color: black
# Start: 3
# Finish: 6
# Parent: z
#
# Node: z
# Color: gray
# Start: 2
# Finish: -1
# Parent: s
#
# Node: w
# Color: gray
# Start: 7
# Finish: -1
# Parent: z
#
# Node: w
# Color: black
# Start: 7
# Finish: 8
# Parent: z
#
# Node: z
# Color: gray
# Start: 2
# Finish: -1
# Parent: s
#
# Node: z
# Color: black
# Start: 2
# Finish: 9
# Parent: s
#
# Node: s
# Color: gray
# Start: 1
# Finish: -1
# Parent: None
#
# Node: s
# Color: black
# Start: 1
# Finish: 10
# Parent: None
#
# Node: t
# Color: gray
# Start: 11
# Finish: -1
# Parent: None
#
# Node: v
# Color: gray
# Start: 12
# Finish: -1
# Parent: t
#
# Node: v
# Color: black
# Start: 12
# Finish: 13
# Parent: t
#
# Node: t
# Color: gray
# Start: 11
# Finish: -1
# Parent: None
#
# Node: u
# Color: gray
# Start: 14
# Finish: -1
# Parent: t
#
# Node: u
# Color: black
# Start: 14
# Finish: 15
# Parent: t
#
# Node: t
# Color: gray
# Start: 11
# Finish: -1
# Parent: None
#
# Node: t
# Color: black
# Start: 11
# Finish: 16
# Parent: None

# %%
printAllInfo(graph)
# Out:
# Node	 Start	 Finish	 Parent
# s 	 1 	 10 	 None
# t 	 11 	 16 	 None
# u 	 14 	 15 	 t
# v 	 12 	 13 	 t
# w 	 7 	 8 	 z
# x 	 4 	 5 	 y
# y 	 3 	 6 	 z
# z 	 2 	 9 	 s
